# %% [markdown]
# # Bayesian Machine Learning:  - Applying Bayes Classifiers

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2022-06-24 10:07:59--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   158MB/s    in 0.4s
#
# 2022-06-24 10:08:00 (158 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 2197 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 1338 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 245  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 11  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 12143  1709.02840v1  This monograph aims at providing an introducti...    cs
# 23849   1109.5453v4  We propose a Bayesian image super-resolution (...    cs
# 28882  1707.09733v2  We propose a new deep learning based approach ...    cs
# 36972  1601.03411v5  We present an alternative methodology for the ...    cs
# 25261  1507.00101v2  This paper presents a simple yet effective sup...    cs
# ...             ...                                                ...   ...
# 22894  1710.03276v1  Identifying changes in the generative process ...  stat
# 21729   1210.7665v2  Many real world network problems often concern...  stat
# 6908   1707.05010v1  Modeling physiological time-series in ICU is o...    cs
# 7555   1802.03360v3  Information planning enables faster learning w...  stat
# 11707  1610.03483v4  Generative adversarial networks (GANs) provide...  stat
#
#                                                    title  year  \
# 12143  A Brief Introduction to Machine Learning for E...  2017
# 23849  Posterior Mean Super-resolution with a Causal ...  2011
# 28882  Camera Relocalization by Computing Pairwise Re...  2017
# 36972      Analysis of Algorithms and Partial Algorithms  2016
# 25261  Supervised Learning of Semantics-Preserving Ha...  2015
# ...                                                  ...   ...
# 22894  Lagged Exact Bayesian Online Changepoint Detec...  2017
# 21729         Graph Estimation From Multi-attribute Data  2012
# 6908              Deep Learning to Attend to Risk in ICU  2017
# 7555                  Information Planning for Text Data  2018
# 11707             Learning in Implicit Generative Models  2016
#
#                                                 keywords
# 12143  [monograph, providing, introduction, algorithm...
# 23849  [resolution, technique, spatially, resolution,...
# 28882  [relocalization, localizes, convolutional, ret...
# 36972  [alternative, methodology, algorithms, discoun...
# 25261  [effective, supervised, constructs, attributes...
# ...                                                  ...
# 22894  [identifying, generative, sequential, changepo...
# 21729  [multivariate, attributes, univariate, attribu...
# 6908   [physiological, importance, collected, irregul...
# 7555   [information, particularly, applicable, advant...
# 11707  [generative, adversarial, algorithmic, framewo...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 12143    [monograph, providing, introduction, algorithm...
# 23849    [resolution, technique, spatially, resolution,...
# 28882    [relocalization, localizes, convolutional, ret...
# 36972    [alternative, methodology, algorithms, discoun...
# 25261    [effective, supervised, constructs, attributes...
#                                ...
# 7499     [dimensional, discriminant, successful, dimens...
# 20362    [prediction, important, ultraviolet, radiation...
# 18067    [framework, preference, programming, introduce...
# 23896    [eigenvector, presented, recognize, expression...
# 36589    [mathematical, formalism, significant, effecti...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8802 words.
# Out of those 4600 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="049cb653-fcc0-4627-8fab-6581da15aab3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("049cb653-fcc0-4627-8fab-6581da15aab3")) {                    Plotly.newPlot(                        "049cb653-fcc0-4627-8fab-6581da15aab3",                        [{"x":["providing","motivations","numerical","introduction","exhaustive","probabilistic","literature","monograph","reproducible","approximate","framework","categories","according","treatment","undirected","supervised","inference","theoretical","solutions","information","statistical","frequentist","including","unsupervised","algorithms","electrical","probability","conclusions","background","generative","optimization","discriminative","frameworks","graphical","mathematical","principles","theoretic","organizes","approaches","engineers","resolution","technique","posterior","estimator","determines","transformation","preferable","numerically","likelihood","objective","distributions","posteriori","generally","variational","hyperparameter","dimensional","evaluated","marginalized","estimates","approximately","spatially","overfitting","conjugate","determined","approximations","parameters","distribution","comparable","experimental","complicated","computing","available","scalability","localizes","orientation","estimation","retrieving","triangulation","generalizes","translation","contribution","localisation","registered","coordinate","benchmark","hypothesis","favourably","previously","different","predicting","challenging","convolutional","relocalization","originally","discounted","artificial","undecidable","alternative","definition","analyzing","intelligence","automated","developed","difficult","following","methodology","terminate","environment","improving","audiences","naturally","minimizing","properties","characteristic","outperforms","desirable","functions","architecture","effective","enhancement","retrieval","preserving","attribute","assumption","attributes","semantics","benchmarks","representations","classification","performance","constructs","prediction","suggesting","identities","represents","describes","competition","challenge","effectively","predictions","annealing","introduce","combining","simulated","anonymized","application","predictor","competitions","algorithm","anonymization","additional","computational","characterization","satisfied","applications","coherence","guarantee","regarding","complement","samplings","validation","implications","condition","completion","incomplete","deterministic","conditions","experiments","complexity","efficiently","uncharted","foundation","interpretable","understand","necessary","segmentation","isolation","algorithmic","recognition","directions","community","traditionally","challenges","unification","annotations","continuous","adversely","specifically","corrected","potential","debugging","resources","demonstrate","inspection","combinatorial","trustworthy","correctly","investigate","techniques","effectiveness"],"y":[83,4,64,36,19,138,132,2,3,102,578,85,111,29,18,194,194,145,164,731,150,2,239,166,585,7,157,21,77,110,341,93,40,63,74,31,56,4,450,5,134,237,39,25,16,67,9,10,79,177,121,6,75,52,11,177,143,3,79,27,17,28,7,40,35,243,190,114,373,27,130,325,46,3,25,211,18,4,30,106,74,2,4,37,223,48,2,113,771,78,259,400,2,15,4,146,6,96,39,57,112,98,201,148,91,69,5,117,104,2,68,57,180,17,268,33,214,241,256,33,114,43,43,60,71,102,94,240,508,959,13,235,13,5,35,81,29,163,124,74,14,330,97,64,2,237,23,5,821,1,113,291,27,10,445,18,51,44,18,0,48,26,48,27,37,35,126,609,234,181,1,21,29,57,86,207,3,48,388,33,68,22,110,7,74,126,4,176,10,170,9,59,547,9,39,3,32,126,376,216],"type":"bar"},{"x":["providing","motivations","numerical","introduction","exhaustive","probabilistic","literature"," ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4600,), (4600, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8108333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Monte</span> <span style=''>Carlo</span> <span style=''>Methods</span> <span style=''>for</span> <span style=''>Tempo</span> <span style=''>Tracking</span> <span style=''>and</span> <span style=''>Rhythm</span> <span style='background-color:rgba(0, 255, 0, 0.375);'>Quantization</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generative</span> <span style=''>model</span> <span style=''>for</span> <span style=''>timing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>deviations</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expressive</span> <span style=''>music</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>of</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>model</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>equivalent</span> <span style=''>to</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>switching</span> <span style=''>state</span> <span style=''>space</span> <span style=''>model</span> <span style=''>The</span> <span style=''>switch</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>variables</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correspond</span> <span style=''>to</span> <span style=''>discrete</span> <span style=''>note</span> <span style='background-color:rgba(0, 255, 0, 0.4193548387096775);'>locations</span> <span style=''>as</span> <span style=''>in</span> <span style=''>a</span> <span style=''>musical</span> <span style=''>score</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style=''>hidden</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>variables</span> <span style=''>denote</span> <span style=''>the</span> <span style=''>tempo</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulate</span> <span style=''>two</span> <span style=''>well</span> <span style=''>known</span> <span style=''>music</span> <span style='background-color:rgba(0, 255, 0, 0.6616702355460387);'>recognition</span> <span style=''>problems</span> <span style=''>namely</span> <span style=''>tempo</span> <span style=''>tracking</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.5999999999999999);'>automatic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transcription</span> <span style=''>(rhythm</span> <span style=''>quantization)</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>filtering</span> <span style=''>and</span> <span style=''>maximum</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.4285714285714286);'>posteriori</span> <span style=''>(MAP)</span> <span style=''>state</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>tasks</span> <span style=''>Exact</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computation</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.6119402985074627);'>posterior</span> <span style=''>features</span> <span style=''>such</span> <span style=''>as</span> <span style=''>the</span> <span style=''>MAP</span> <span style=''>state</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intractable</span> <span style=''>in</span> <span style=''>this</span> <span style=''>model</span> <span style=''>class</span> <span style=''>so</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>Monte</span> <span style=''>Carlo</span> <spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Dictionary</span> <span style=''>LASSO</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Guaranteed</span> <span style=''>Sparse</span> <span style=''>Recovery</span> <span style=''>under</span> <span style=''>Linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Transformation</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>following</span> <span style=''>signal</span> <span style=''>recovery</span> <span style=''>problem</span> <span style=''>given</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>measurement</span> <span style=''>matrix</span> <span style=''>Phiin</span> <span style=''>mathbbRntimes</span> <span style=''>p</span> <span style=''>and</span> <span style=''>a</span> <span style=''>noisy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observation</span> <span style=''>vector</span> <span style=''>cin</span> <span style=''>mathbbRn</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constructed</span> <span style=''>from</span> <span style=''>c</span> <span style=''>Phitheta</span> <span style=''>epsilon</span> <span style=''>where</span> <span style=''>epsilonin</span> <span style=''>mathbbRn</span> <span style=''>is</span> <span style=''>the</span> <span style=''>noise</span> <span style=''>vector</span> <span style=''>whose</span> <span style=''>entries</span> <span style=''>follow</span> <span style=''>iid</span> <span style=''>centered</span> <span style=''>sub</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>how</span> <span style=''>to</span> <span style=''>recover</span> <span style=''>the</span> <span style=''>signal</span> <span style=''>theta</span> <span style=''>if</span> <span style=''>Dtheta</span> <span style=''>is</span> <span style=''>sparse</span> <span style=''>rca</span> <span style=''>under</span> <span style=''>a</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transformation</span> <span style=''>DinmathbbRmtimes</span> <span style=''>p</span> <span style=''>One</span> <span style=''>natural</span> <span style=''>method</span> <span style=''>using</span> <span style=''>convex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>is</span> <span style=''>to</span> <span style=''>solve</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>following</span> <span style=''>problem</span> <span style=''>min</span> <span style=''>theta</span> <span style=''>1over</span> <span style=''>2|Phitheta</span> <span style=''>c|2</span> <span style=''>lambda|Dtheta|</span> <span style=''>1</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>provides</span> <span style=''>an</span> <span style=''>upper</span> <span style=''>bound</span> <span style=''>of</span> <span style=''>the</span> <span style=''>estimate</span> <span style=''>error</span> <span style=''>and</span> <span style=''>shows</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistency</span> <span style=''>property</span> <span style=''>of</span> <span style=''>this</span> <span style=''>method</span> <span style=''>by</span> <span style=''>assuming</span> <span style=''>that</span> <span style=''>the</span> <span style=''>design</span> <span style=''>matrix</span> <span style=''>Phi</span> <span style=''>is</span> <span style=''>a</span> <span style=''>Gaussian</span> <span style=''>random</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Specifically</span> <span style=''>we</span> <span style=''>show</span> <span style=''>1)</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Solving</span> <span style=''>the</span> <span style=''>Goddard</span> <span style=''>problem</span> <span style=''>by</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>influence</span> <span style=''>diagram</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Influence</span> <span style=''>diagrams</span> <span style=''>are</span> <span style=''>a</span> <span style=''>decision</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extension</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>graphical</span> <span style=''>models</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>show</span> <span style=''>how</span> <span style=''>they</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>to</span> <span style=''>solve</span> <span style=''>the</span> <span style=''>Goddard</span> <span style=''>problem</span> <span style=''>We</span> <span style=''>present</span> <span style=''>results</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.5276752767527675);'>numerical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>experiments</span> <span style=''>with</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>and</span> <span style=''>compare</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3497942386831276);'>solutions</span> <span style=''>provided</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>influence</span> <span style=''>diagrams</span> <span style=''>with</span> <span style=''>the</span> <span style=''>optimal</span> <span style=''>solution</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Collaborative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Filtering</span> <span style=''>using</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Denoising</span> <span style=''>Auto</span> <span style=''>Encoders</span> <span style=''>for</span> <span style=''>Market</span> <span style=''>Basket</span> <span style=''>Data</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Recommender</span> <span style=''>systems</span> <span style=''>(RS)</span> <span style=''>help</span> <span style=''>users</span> <span style=''>navigate</span> <span style=''>large</span> <span style=''>sets</span> <span style=''>of</span> <span style=''>items</span> <span style=''>in</span> <span style=''>the</span> <span style=''>search</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interesting</span> <span style=''>ones</span> <span style=''>One</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>RS</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Collaborative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Filtering</span> <span style=''>(CF)</span> <span style=''>which</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>idea</span> <span style=''>that</span> <span style=''>similar</span> <span style=''>users</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interested</span> <span style=''>in</span> <span style=''>similar</span> <span style=''>items</span> <span style=''>Most</span> <span style=''>model</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>to</span> <span style=''>CF</span> <span style=''>seek</span> <span style=''>to</span> <span style=''>train</span> <span style=''>a</span> <span style=''>machine</span> <span style=''>learningdata</span> <span style=''>mining</span> <span style=''>model</span> <span style=''>based</span> <span style=''>on</span> <span style=''>sparse</span> <span style=''>data</span> <span style=''>the</span> <span style=''>model</span> <span style=''>is</span> <span style=''>then</span> <span style=''>used</span> <span style=''>to</span> <span style=''>provide</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recommendations</span> <span style=''>While</span> <span style=''>most</span> <span style=''>of</span> <span style=''>the</span> <span style=''>proposed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effective</span> <span style=''>for</span> <span style=''>small</span> <span style=''>size</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>situations</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combinatorial</span> <span style=''>nature</span> <span style=''>of</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>makes</span> <span style=''>it</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>impractical</span> <span style=''>for</span> <span style=''>medium</span> <span style=''>to</span> <span style=''>large</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>instances</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>CF</span> <span style=''>that</span> <span style=''>works</span> <span style=''>by</span> <span style=''>training</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Denoising</span> <span style=''>Auto</span> <span style=''>Encoder</span> <span style=''>(DAE)</s ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	automatic (0.07851534618129907)
# 	architecture (0.08600999286224126)
# 	experimental (0.1331192005710207)
# 	processing (0.10742326909350464)
# 	segmentation (0.07387580299785867)
# 	detection (0.1192005710206995)
# 	information (0.26088508208422556)
# 	different (0.2751605995717345)
# 	recognition (0.13847251962883655)
# 	convolutional (0.14275517487508924)
#
# Some Statistics words are:
# 	numerical (0.1036036036036036)
# 	algorithm (0.38288288288288286)
# 	stochastic (0.13313313313313313)
# 	theoretical (0.15165165165165165)
# 	statistical (0.15665665665665665)
# 	estimation (0.17867867867867868)
# 	distribution (0.17217217217217218)
# 	inference (0.1891891891891892)
# 	dimensional (0.1921921921921922)
# 	regression (0.18468468468468469)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="534b4a40-8743-457c-8951-1715b6e17440" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("534b4a40-8743-457c-8951-1715b6e17440")) {                    Plotly.newPlot(                        "534b4a40-8743-457c-8951-1715b6e17440",                        [{"x":["providing","motivations","numerical","introduction","exhaustive","probabilistic","literature","monograph","reproducible","approximate","framework","categories","according","treatment","undirected","supervised","inference","theoretical","solutions","information","statistical","frequentist","including","unsupervised","algorithms","electrical","probability","conclusions","background","generative","optimization","discriminative","frameworks","graphical","mathematical","principles","theoretic","organizes","approaches","engineers","resolution","technique","posterior","estimator","determines","transformation","preferable","numerically","likelihood","objective","distributions","posteriori","generally","variational","hyperparameter","dimensional","evaluated","marginalized","estimates","approximately","spatially","overfitting","conjugate","determined","approximations","parameters","distribution","comparable","experimental","complicated","computing","available","scalability","localizes","orientation","estimation","retrieving","triangulation","generalizes","translation","contribution","localisation","registered","coordinate","benchmark","hypothesis","favourably","previously","different","predicting","challenging","convolutional","relocalization","originally","discounted","artificial","undecidable","alternative","definition","analyzing","intelligence","automated","developed","difficult","following","methodology","terminate","environment","improving","audiences","naturally","minimizing","properties","characteristic","outperforms","desirable","functions","architecture","effective","enhancement","retrieval","preserving","attribute","assumption","attributes","semantics","benchmarks","representations","classification","performance","constructs","prediction","suggesting","identities","represents","describes","competition","challenge","effectively","predictions","annealing","introduce","combining","simulated","anonymized","application","predictor","competitions","algorithm","anonymization","additional","computational","characterization","satisfied","applications","coherence","guarantee","regarding","complement","samplings","validation","implications","condition","completion","incomplete","deterministic","conditions","experiments","complexity","efficiently","uncharted","foundation","interpretable","understand","necessary","segmentation","isolation","algorithmic","recognition","directions","community","traditionally","challenges","unification","annotations","continuous","adversely","specifically","corrected","potential","debugging","resources","demonstrate","inspection","combinatorial","trustworthy","correctly","investigate","techniques","effectiveness","positions","combination","principal","significant","improvement","component","comparison","comparably","boundaries","maximally","typically","aggregation","associated","illustrated","intensity","structure","significantly","detection","especially","sequences","performing","detectors","circumstances","particular","description","differentiable","illustrate","furthermore","classroom","nonlinear","investigated","rademacher","generalization","efficiency","generated","important","functional","therefore","privileged","interaction","mechanism","competitive","conjunction","spatiotemporal","perception","dictionary","practical","formalisms","descriptions","linguistic","presented","conceptual","cognitive","represented","commercial","relationships","currently","composit ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	samplings
# 	whitening
# 	reparametrization
# 	reparametrizations
# 	reflectivity
# 	spectroradiometer
# 	nonparametrics
# 	integrative
# 	exchanges
# 	integrable
# 	minimizer
# 	regressions
# 	statistician
# 	nonparametrically
# 	macroeconomic
# 	abundances
# 	eigendecomposition
# 	conjugacy
# 	extrapolating
# 	aggregations
# Some words which never appear in Statistics papers:
# 	organizes
# 	engineers
# 	triangulation
# 	relocalization
# 	undecidable
# 	audiences
# 	adversely
# 	trustworthy
# 	formalisms
# 	coordinated
# 	dependently
# 	intentions
# 	achievements
# 	offspring
# 	mastermind
# 	programmable
# 	processor
# 	multiplexing
# 	amalgamation
# 	formalising

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0656039239730225e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.765
